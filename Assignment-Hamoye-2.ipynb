# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv(r"C:\Users\IKHLAS SALMAN\Desktop\Hamoye\energydata_complete.csv")
df.head(20)
# Out:
#                    date  Appliances  lights         T1       RH_1         T2  \
# 0   2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 1   2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2   2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 3   2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 4   2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# 5   2016-01-11 17:50:00          50      40  19.890000  46.026667  19.200000
# 6   2016-01-11 18:00:00          60      50  19.890000  45.766667  19.200000
# 7   2016-01-11 18:10:00          60      50  19.856667  45.560000  19.200000
# 8   2016-01-11 18:20:00          60      40  19.790000  45.597500  19.200000
# 9   2016-01-11 18:30:00          70      40  19.856667  46.090000  19.230000
# 10  2016-01-11 18:40:00         230      70  19.926667  45.863333  19.356667
# ...

# %%
x = df['T2'].values.reshape(-1, 1)
y = df['T6'].values

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)

# %%
print('R^2 value:', round(r2, 2))
# Out:
# R^2 value: 0.64

# %%
columns_to_remove = ["date", "lights"]
df = df.drop(columns_to_remove, axis=1)

# %%
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
X
# Out:
#               T1       RH_1         T2       RH_2         T3       RH_3  \
# 0      19.890000  47.596667  19.200000  44.790000  19.790000  44.730000
# 1      19.890000  46.693333  19.200000  44.722500  19.790000  44.790000
# 2      19.890000  46.300000  19.200000  44.626667  19.790000  44.933333
# 3      19.890000  46.066667  19.200000  44.590000  19.790000  45.000000
# 4      19.890000  46.333333  19.200000  44.530000  19.790000  45.000000
# ...          ...        ...        ...        ...        ...        ...
# 19730  25.566667  46.560000  25.890000  42.025714  27.200000  41.163333
# 19731  25.500000  46.500000  25.754000  42.080000  27.133333  41.223333
# 19732  25.500000  46.596667  25.628571  42.768571  27.050000  41.690000
# 19733  25.500000  46.990000  25.414000  43.036000  26.890000  41.290000
# 19734  25.500000  46.600000  25.264286  42.971429  26.823333  41.156667
#
#               T4       RH_4         T5       RH_5  ...         T9     RH_9  \
# ...

# %%
X = df.drop("Appliances", axis=1)
y = df["Appliances"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.3, random_state=42)

# %%
model1 = LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model1.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

# %%
print('Mean Absolute Error:', round(mae, 2))
# Out:
# Mean Absolute Error: 53.64

# %%
rss = mean_squared_error(y_test, y_pred) * len(y_test)
print('Residual Sum of Squares (RSS):', round(rss,2))
# Out:
# Residual Sum of Squares (RSS): 51918501.21

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('Root Mean Squared Error (RMSE):', round(rmse, 3))
# Out:
# Root Mean Squared Error (RMSE): 93.64

# %%
r_squared = r2_score(y_test, y_pred)
print('Coefficient of Determination (R-squared):', round(r_squared, 2))
# Out:
# Coefficient of Determination (R-squared): 0.15

# %%
feature_weights = pd.Series(model1.coef_, index=X.columns)

# Find features with lowest and highest weights
feature_with_lowest_weight = feature_weights.idxmin()
feature_with_highest_weight = feature_weights.idxmax()

print('Feature with the lowest weight:', feature_with_lowest_weight)
print('Feature with the highest weight:', feature_with_highest_weight)
# Out:
# Feature with the lowest weight: RH_2
# Feature with the highest weight: RH_1

# %%
alpha = 0.4
ridge_model = Ridge(alpha=alpha)
ridge_model.fit(X_train, y_train)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print('Root Mean Squared Error (RMSE) on test set:', rmse)
# Out:
# Root Mean Squared Error (RMSE) on test set: 93.64046093998029

# %%
lpha = 0.001
lasso_model = Lasso(alpha=alpha)
lasso_model.fit(X, y)

# Get the feature weights
feature_weights = lasso_model.coef_

# Count the number of non-zero feature weights
non_zero_features = sum(feature_weights != 0)

print('Number of features with non-zero feature weights:', non_zero_features)
# Out:
# Number of features with non-zero feature weights: 23

# %%
df.shape
# Out:
# (19735, 27)

# %%
df.columns
# Out:
# Index(['Appliances', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4',
#        'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9',
#        'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# date           False
# Appliances     False
# lights         False
# T1             False
# RH_1           False
# T2             False
# RH_2           False
# T3             False
# RH_3           False
# T4             False
# RH_4           False
# T5             False
# RH_5           False
# T6             False
# RH_6           False
# T7             False
# RH_7           False
# T8             False
# RH_8           False
# T9             False
# RH_9           False
# T_out          False
# Press_mm_hg    False
# RH_out         False
# Windspeed      False
# Visibility     False
# Tdewpoint      False
# rv1            False
# rv2            False
# dtype: bool

# %%
df.isnull().any().sum()
# Out:
# 0
